# %%
import pandas as pd
                    #C:\Users\ANNIE CHRISTINA G\Desktop\data spark\dataset\Customers.csv
sales = pd.read_csv('C:/Users/ANNIE CHRISTINA G/Desktop/data spark/dataset/Sales.csv')
#customer = pd.read_csv('C:/Users/ANNIE CHRISTINA G/Desktop/data spark/dataset/Customers.csv')

# Try different encodings if one doesn't work
customer = pd.read_csv('C:/Users/ANNIE CHRISTINA G/Desktop/data spark/dataset/Customers.csv', encoding='latin1')
# or
# customer = pd.read_csv('C:/Users/ANNIE CHRISTINA G/Desktop/data spark/dataset/Customers.csv', encoding='iso-8859-1')
# or
# customer = pd.read_csv('C:/Users/ANNIE CHRISTINA G/Desktop/data spark/dataset/Customers.csv', encoding='cp1252')
stores = pd.read_csv('C:/Users/ANNIE CHRISTINA G/Desktop/data spark/dataset/Stores.csv')
product = pd.read_csv('C:/Users/ANNIE CHRISTINA G/Desktop/data spark/dataset/Products.csv')
exra = pd.read_csv('C:/Users/ANNIE CHRISTINA G/Desktop/data spark/dataset/Exchange_Rates.csv')

# %%
customer
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
sales['Delivery Date']=sales['Delivery Date'].fillna(sales['Delivery Date'].mode()[0])

# %%
sales
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1   1/1/2016      1/6/2020       265598
# 1            366001          1   1/1/2016     1/13/2016      1269051
# 2            366001          2   1/1/2016     1/13/2016      1269051
# 3            366002          1   1/1/2016     1/12/2016       266019
# 4            366002          2   1/1/2016     1/12/2016       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1  2/20/2021      1/6/2020      1216913
# 62880       2243031          1  2/20/2021     2/24/2021       511229
# 62881       2243032          1  2/20/2021     2/23/2021       331277
# 62882       2243032          2  2/20/2021     2/23/2021       331277
# 62883       2243032          3  2/20/2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
product
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit Cost USD Unit Price USD  SubcategoryKey  \
# ...

# %%
exra
# Out:
#             Date Currency  Exchange
# 0       1/1/2015      USD    1.0000
# 1       1/1/2015      CAD    1.1583
# 2       1/1/2015      AUD    1.2214
# 3       1/1/2015      EUR    0.8237
# 4       1/1/2015      GBP    0.6415
# ...          ...      ...       ...
# 11210  2/20/2021      USD    1.0000
# 11211  2/20/2021      CAD    1.2610
# 11212  2/20/2021      AUD    1.2723
# 11213  2/20/2021      EUR    0.8238
# 11214  2/20/2021      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
stores
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#     Open Date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# ...

# %%
print(customer.isna().sum())
print(product.isna().sum())
print(sales.isna().sum())
print(stores.isna().sum())
print(exra.isna().sum())
# Out:
# CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64
# ProductKey        0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64
# Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# dtype: int64
# StoreKey         0
# Country          0
# State            0
# Square Meters    1
# Open Date        0
# dtype: int64
# Date        0
# Currency    0
# Exchange    0
# dtype: int64

# %%
##customer['State Code']=customer['State Code'].fillna(customer['State Code'].mode()[0])

# %%
import pandas as pd

# Load the CSV file into a DataFrame with the correct encoding
file_path = 'C:/Users/ANNIE CHRISTINA G/Desktop/data spark/dataset/Customers.csv'
df = pd.read_csv(file_path, encoding='latin1')

# Create a mapping of state names to their corresponding state codes
state_code_mapping = {
    'Queensland': 'QLD',
    'New South Wales': 'NSW',
    'South Australia': 'SA',
    'Victoria': 'VIC',
    'Western Australia': 'WA',
    'Tasmania': 'TAS',
    'Northern Territory': 'NT',
    'Australian Capital Territory': 'ACT'
}

# Fill missing state codes using the mapping and generate dynamically if not in mapping
df['State Code'] = df.apply(
    lambda row: state_code_mapping.get(
        row['State'],
        ''.join([word[:2].upper() for word in row['State'].split()] if len(row['State'].split()) > 1 else row['State'][:3].upper())
    ) if pd.isnull(row['State Code']) or row['State Code'] == '' else row['State Code'], axis=1)

# Save the updated DataFrame back to a CSV file
updated_file_path = 'C:/Users/ANNIE CHRISTINA G/Desktop/data spark/dataset/updated_customers.csv'
df.to_csv(updated_file_path, index=False)

print(f"Missing state codes have been filled and the updated file has been saved as '{updated_file_path}'.")
# Out:
# Missing state codes have been filled and the updated file has been saved as 'C:/Users/ANNIE CHRISTINA G/Desktop/data spark/dataset/updated_customers.csv'.

# %%
import pandas as pd

# Load the CSV file into a DataFrame
file_path = 'C:/Users/ANNIE CHRISTINA G/Desktop/data spark/dataset/Customers.csv'
df = pd.read_csv(file_path)

# Create a mapping of state names to their corresponding state codes for common states
state_code_mapping = {
    'Queensland': 'QLD',
    'New South Wales': 'NSW',
    'South Australia': 'SA',
    'Victoria': 'VIC',
    'Western Australia': 'WA',
    'Tasmania': 'TAS',
    'Northern Territory': 'NT',
    'Australian Capital Territory': 'ACT'
    # Extend this dictionary as needed for known states
}

# Function to dynamically generate a state code
def generate_state_code(state):
    words = state.split()
    if len(words) == 1:
        return state[:3].upper()
    else:
        return ''.join([word[:2].upper() for word in words])

# Fill missing state codes using the mapping and generate dynamically if not in mapping
df['State Code'] = df.apply(
    lambda row: state_code_mapping.get(row['State'], generate_state_code(row['State']))
    if pd.isnull(row['State Code']) or row['State Code'] == ''
    else row['State Code'], axis=1)

# Save the updated DataFrame back to a CSV file
updated_file_path = 'updated1_customers.csv'
df.to_csv(updated_file_path, index=False)

print(f"Missing state codes have been filled and the updated file has been saved as '{updated_file_path}'.")
# Out:
# Missing state codes have been filled and the updated file has been saved as 'updated1_customers.csv'.
